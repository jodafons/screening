# %%
import pandas as pd
import numpy as np
import pickle
import requests
import json
import os, sys
import argparse


from PIL import Image as Img
from PIL import ImageOps
from tqdm import tqdm
from itertools import compress
from sklearn.model_selection import StratifiedKFold
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import pickle
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/compat/__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# !pip install --upgrade pandas pandasai
# Out:
# Requirement already satisfied: pandas in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (1.5.3)
# Collecting pandas
#   Using cached pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting pandasai
#   Downloading pandasai-2.4.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.4 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandas) (2024.2)
# Collecting astor<0.9.0,>=0.8.1 (from pandasai)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting duckdb<2.0.0,>=1.0.0 (from pandasai)
#   Downloading duckdb-1.1.3-cp310-cp310-macosx_12_0_arm64.whl.metadata (762 bytes)
# Collecting faker<20.0.0,>=19.12.0 (from pandasai)
#   Downloading Faker-19.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandasai) (3.1.5)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandasai) (3.10.0)
# Collecting openai<2 (from pandasai)
#   Downloading openai-1.59.6-py3-none-any.whl.metadata (27 kB)
# Collecting pillow<11.0.0,>=10.1.0 (from pandasai)
#   Downloading pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandasai) (2.10.5)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from pandasai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pandasai) (2.32.3)
# Collecting scipy<2.0.0,>=1.9.0 (from pandasai)
#   Downloading scipy-1.15.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting sqlalchemy<3,>=1.4 (from pandasai)
#   Downloading SQLAlchemy-2.0.37-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting sqlglot<26.0.0,>=25.0.3 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglot-25.34.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from openai<2->pandasai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai<2->pandasai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from openai<2->pandasai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2->pandasai)
#   Downloading jiter-0.8.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from openai<2->pandasai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from openai<2->pandasai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from openai<2->pandasai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pydantic<3,>=1->pandasai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from pydantic<3,>=1->pandasai) (2.27.2)
# Requirement already satisfied: six>=1.5 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2024.12.14)
# Collecting sqlglotrs==0.3.0 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglotrs-0.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (545 bytes)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2->pandasai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2->pandasai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jodafons/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->pandasai) (0.14.0)
# Downloading pandasai-2.4.2-py3-none-any.whl (193 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading duckdb-1.1.3-cp310-cp310-macosx_12_0_arm64.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 1.5 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading openai-1.59.6-py3-none-any.whl (454 kB)
# Downloading pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 835.0 kB/s eta 0:00:00 kB/s eta 0:00:01:02
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading scipy-1.15.0-cp310-cp310-macosx_14_0_arm64.whl (24.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 1.6 MB/s eta 0:00:000:00:010:00:01:01
# Downloading SQLAlchemy-2.0.37-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading sqlglot-25.34.1-py3-none-any.whl (435 kB)
# Downloading sqlglotrs-0.3.0-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.8.2-cp310-cp310-macosx_11_0_arm64.whl (311 kB)
# Installing collected packages: sqlglotrs, sqlglot, sqlalchemy, scipy, python-dotenv, pillow, jiter, duckdb, distro, astor, faker, openai, pandasai
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dorothy-sdk 1.4.8 requires Pillow==9.5.0, but you have pillow 10.4.0 which is incompatible.
# Successfully installed astor-0.8.1 distro-1.9.0 duckdb-1.1.3 faker-19.13.0 jiter-0.8.2 openai-1.59.6 pandasai-2.4.2 pillow-10.4.0 python-dotenv-1.0.1 scipy-1.15.0 sqlalchemy-2.0.37 sqlglot-25.34.1 sqlglotrs-0.3.0

# %%
def stratified_train_val_test_splits(df, n_folds,seed=512):
    cv_index = {'train_val': [], 'test': []}
    cv_train_test = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)
    sorts_train_test = []
    for train_val_idx, test_idx in cv_train_test.split(df.values, df.target.values):
        cv_index['test'].append(test_idx)
        cv_index['train_val'].append(train_val_idx)
    fold_idx = set(np.arange(0, n_folds, 1))
    for fold in fold_idx:
        val_idx = list(fold_idx - set([fold]))
        print('bins selected for val: ' + str(val_idx))
        sorts = []
        for i in tqdm(val_idx):
            l_val_idx = cv_index['test'][i]
            flt = ~pd.Series(cv_index['train_val'][fold]).isin(l_val_idx).values
            l_train_idx = np.array(list(compress(cv_index['train_val'][fold], flt)))
            sorts.append((l_train_idx, l_val_idx, cv_index['test'][fold]))
        sorts_train_test.append(sorts)
    return sorts_train_test




class Client:

    def __init__(self, token):
        self.__header = { "Authorization": 'Token '+token}

    def dataset(self, name):
        response = requests.get('https://dorothy-image.lps.ufrj.br/images/?search={DATASET}'.format(DATASET=name), 
                                headers=self.__header)
        data = json.loads(response.content)
        return Dataset(data, self.__header)
    


class Dataset:

    def __init__(self, data, header ):
        self.__header = header
        self.__images = [Image(d, self.__header) for d in data]

    def list_images(self):
        return self.__images


class Image:

    def __init__(self, raw, header):
        self.__header = header
        self.dataset_name = raw['dataset_name']
        self.project_id = raw['project_id']
        self.image_url = raw['image_url']
        self.metadata = raw['metadata']
        self.date_acquisition = raw['date_acquisition']
        self.insertion_date = raw['insertion_date']

    def download( self, output):
        file = open(output,"wb")
        response = requests.get(self.image_url, headers=self.__header)
        file.write(response.content)
        file.close()

        # fix image 
        img = Img.open(output)
        img = ImageOps.exif_transpose(img)
        img.save(output)


        


#
# Decorate with targets
#


def china_label(metadata):
    return metadata['has_tb']
def imageamento_label(metadata):
    return False
def imageamento_anonimizado_valid_label(metadata):
    return False
def manaus_label(metadata):
    return metadata['has_tb']
def russia_label(metadata):
    return metadata['has_tb']


datasets = {
                'china'                         : china_label,
                'manaus'                        : manaus_label,
                'c_manaus'                      : manaus_label,
                'imageamento'                   : imageamento_label,
                'imageamento_anonimizado_valid' : imageamento_anonimizado_valid_label,
                'russia'                        : russia_label,
}

#
# Dataset
#

class DownloadDataset:

    """Download specified dataset from Dorothy"""


    def __init__(self,token, tests = 10, seed = 512):
        self.service = Client(token=token)
        self.seed = seed
        self.tests = tests

        

    def download(self, dataset_name, basepath):

        if not dataset_name in datasets.keys():
            raise(f'Dataset ({dataset_name}) not supported.')

        output_images = basepath + '/images'
        # Creating output dir    
        os.makedirs(output_images, exist_ok=True)
        dataset = self.service.dataset(dataset_name)

        # template
        d = {
            'dataset_name'     : [],
            'project_id'       : [],
            #'target'          : [],
            #'image_md5'       : [],
            #'image_url'       : [],
            'image_path'       : [],
            'insertion_date'   : [],
            'metadata'         : [],
            #'date_acquisition': [],
            #'number_reports'  : [],
            'target'           : [],
        }

        # Download each image
        for image in tqdm(dataset.list_images()):
            d['dataset_name'].append(image.dataset_name)
            d['project_id'].append(image.project_id)
            image_path = output_images+'/%s'%(image.project_id)+'.png' 
            if not os.path.exists(image_path):
                image.download(image_path)
            d['image_path'].append(  'images/'+image.project_id+'.png')
            d['metadata'].append(image.metadata)
            d['insertion_date'].append(image.insertion_date)
            d['target'].append(datasets[dataset_name](image.metadata))
        df = pd.DataFrame(d)
        df = df.sort_values('project_id')
        df.to_csv(basepath+'/images.csv')

        with open(basepath+'/splits.pic','wb') as f:
            splits = stratified_train_val_test_splits(df,self.tests,self.seed)
            pickle.dump(splits,f)


        return df




def download( tag , output_folder, token : str=os.environ.get("DOROTHY_TOKEN","") ):
  api = DownloadDataset(token)
  df  = api.download(tag, output_folder)
  return df

token = "b16fe0fc92088c4840a98160f3848839e68b1148"
df = download( token , 'china', 'test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 __all__ = ['download', 'stratified_train_val_test_splits']
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import pickle
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/compat/__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/Desktop/git_repos/screening/screening-env/lib/python3.10/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
